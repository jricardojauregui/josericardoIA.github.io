# %%
# Importar las librerías
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('obesidad.csv')
print(df.shape)
df.head()
# Out:
# (2111, 10)
#      Sexo  Edad  Estatura  Peso FamiliarConSobrepeso ComeMuchasCalorias  \
# 0  Female  21.0      1.62  64.0                  yes                 no
# 1  Female  21.0      1.52  56.0                  yes                 no
# 2    Male  23.0      1.80  77.0                  yes                 no
# 3    Male  27.0      1.80  87.0                   no                 no
# 4    Male  22.0      1.78  89.8                   no                 no
#
#    ComeVegetales Fumador  ConsumoDeAgua      NivelDeObesidad
# 0            2.0      no            2.0        Normal_Weight
# 1            3.0     yes            3.0        Normal_Weight
# 2            2.0      no            2.0        Normal_Weight
# 3            3.0      no            2.0   Overweight_Level_I
# 4            2.0      no            2.0  Overweight_Level_II

# %%
df.dtypes
# Out:
# Sexo                     object
# Edad                    float64
# Estatura                float64
# Peso                    float64
# FamiliarConSobrepeso     object
# ComeMuchasCalorias       object
# ComeVegetales           float64
# Fumador                  object
# ConsumoDeAgua           float64
# NivelDeObesidad          object
# dtype: object

# %%
tabla_frec_rel = (df['NivelDeObesidad'].value_counts() / df['NivelDeObesidad'].value_counts().sum())*100
tabla_frec_rel
# Out:
# NivelDeObesidad
# Obesity_Type_I         16.627191
# Obesity_Type_III       15.348176
# Obesity_Type_II        14.069162
# Overweight_Level_I     13.737565
# Overweight_Level_II    13.737565
# Normal_Weight          13.595452
# Insufficient_Weight    12.884889
# Name: count, dtype: float64

# %%
tabla_frec_rel.plot(kind='bar', title = 'Niveles de Obesidad')
pit.xlabel('Nivel de Obesidad')
pit.ylabel('Porcentaje de personas')
pit.show()

# %%
df["bmi"] = df["Peso"] / (df["Estatura"] ** 2)
df.head()
# Out:
#      Sexo  Edad  Estatura  Peso FamiliarConSobrepeso ComeMuchasCalorias  \
# 0  Female  21.0      1.62  64.0                  yes                 no
# 1  Female  21.0      1.52  56.0                  yes                 no
# 2    Male  23.0      1.80  77.0                  yes                 no
# 3    Male  27.0      1.80  87.0                   no                 no
# 4    Male  22.0      1.78  89.8                   no                 no
#
#    ComeVegetales Fumador  ConsumoDeAgua      NivelDeObesidad        bmi
# 0            2.0      no            2.0        Normal_Weight  24.386526
# 1            3.0     yes            3.0        Normal_Weight  24.238227
# 2            2.0      no            2.0        Normal_Weight  23.765432
# 3            3.0      no            2.0   Overweight_Level_I  26.851852
# 4            2.0      no            2.0  Overweight_Level_II  28.342381

# %%
df['bmi'].mode()
# Out:
# 0    26.672763
# Name: bmi, dtype: float64

# %%
df['bmi'].median()
# Out:
# 28.71908906003529

# %%
df['bmi'].plot(kind='hist', bins = 20)
pit.xlabel('BMI')
pit.ylabel('Frecuencia')
pit.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df_hombres = df[df["Sexo"] == "Male"]

# %%
plt.figure(figsize=(7,5))
plt.scatter(df_mujer["Edad"], df_mujer["bmi"])
plt.xlabel("Edad")
plt.ylabel("BMI")
plt.title("BMI vs Edad (Hombres)")
plt.show()
